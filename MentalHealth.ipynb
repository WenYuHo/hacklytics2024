# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("Mental health Depression disorder Data.csv")
df = df[0:6468]
df
# Out:
# /var/folders/_4/rmwdgzks40sgbspscphgg6pw0000gp/T/ipykernel_19072/1116076683.py:4: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Mental health Depression disorder Data.csv")
#       index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0         0  Afghanistan  AFG  1990           0.16056             0.697779
# 1         1  Afghanistan  AFG  1991          0.160312             0.697961
# 2         2  Afghanistan  AFG  1992          0.160135             0.698107
# 3         3  Afghanistan  AFG  1993          0.160037             0.698257
# 4         4  Afghanistan  AFG  1994          0.160022             0.698469
# ...     ...          ...  ...   ...               ...                  ...
# 6463   6463     Zimbabwe  ZWE  2013           0.15567             0.607993
# 6464   6464     Zimbabwe  ZWE  2014          0.155993              0.60861
# ...

# %%
df.filter(items = ["Schizophrenia (%)", "Bipolar Disorder (%)", "Eating disorders (%)", "Anxiety disorders (%)", 
                  "Drug use disorders (%)", "Depression (%)", "Alcohol use disorders (%)"])
# Out:
#      Schizophrenia (%) Eating disorders (%)  Anxiety disorders (%)  \
# 0              0.16056             0.101855               4.828830
# 1             0.160312             0.099313               4.829740
# 2             0.160135             0.096692               4.831108
# 3             0.160037             0.094336               4.830864
# 4             0.160022             0.092439               4.829423
# ...                ...                  ...                    ...
# 6463           0.15567             0.117248               3.090168
# 6464          0.155993             0.118073               3.093964
# 6465          0.156465              0.11947               3.098687
# 6466          0.157111             0.121456               3.104294
# 6467          0.157963             0.124443               3.110926
#
#       Drug use disorders (%)  Depression (%)  Alcohol use disorders (%)
# 0                   1.677082        4.071831                   0.672404
# ...

# %%
grouped_data = df.groupby('Entity')

summary_statistics = grouped_data.describe()

print(summary_statistics)
# Out:
#                            index                                             \
#                            count    mean       std     min      25%     50%
# Entity
# Afghanistan                 28.0    13.5  8.225975     0.0     6.75    13.5
# Albania                     28.0    41.5  8.225975    28.0    34.75    41.5
# Algeria                     28.0    69.5  8.225975    56.0    62.75    69.5
# American Samoa              28.0    97.5  8.225975    84.0    90.75    97.5
# Andean Latin America        28.0   125.5  8.225975   112.0   118.75   125.5
# ...                          ...     ...       ...     ...      ...     ...
# Western Sub-Saharan Africa  28.0  6341.5  8.225975  6328.0  6334.75  6341.5
# World                       28.0  6369.5  8.225975  6356.0  6362.75  6369.5
# Yemen                       28.0  6397.5  8.225975  6384.0  6390.75  6397.5
# Zambia                      28.0  6425.5  8.225975  6412.0  6418.75  6425.5
# ...

# %%
summary_statistics.max(0)
# Out:
# index                      count      28.000000
#                            mean     6453.500000
#                            std         8.225975
#                            min      6440.000000
#                            25%      6446.750000
#                            50%      6453.500000
#                            75%      6460.250000
#                            max      6467.000000
# Anxiety disorders (%)      count      28.000000
#                            mean        8.651309
#                            std         0.330468
#                            min         8.258284
#                            25%         8.533841
#                            50%         8.555936
#                            75%         8.910409
#                            max         8.967330
# Drug use disorders (%)     count      28.000000
#                            mean        2.844713
#                            std         0.372779
#                            min         2.339515
# ...

# %%
min(df["Schizophrenia (%)"])
df[df["Schizophrenia (%)"]== min(df["Schizophrenia (%)"])]
# Out:
#       index      Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 3866   3866  Mozambique  MOZ  1992          0.146902             0.603562
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 3866             0.076041               3.591123                0.488752
#
#       Depression (%)  Alcohol use disorders (%)
# 3866        3.767717                   1.594383

# %%
max(df["Schizophrenia (%)"])
df[df["Schizophrenia (%)"]== max(df["Schizophrenia (%)"])]
# Out:
#       index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 3992   3992  Netherlands  NLD  2006           0.37511             0.947197
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 3992             0.409201               6.512405                0.937893
#
#       Depression (%)  Alcohol use disorders (%)
# 3992        4.046277                   0.722001

# %%
min(df["Anxiety disorders (%)"])
df[df["Anxiety disorders (%)"]== min(df["Anxiety disorders (%)"])]
# Out:
#       index   Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 6259   6259  Vietnam  VNM  2005          0.235363             0.546672
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 6259             0.103511               2.023393                0.649577
#
#       Depression (%)  Alcohol use disorders (%)
# 6259        2.923107                   1.558684

# %%
max(df["Anxiety disorders (%)"])
df[df["Anxiety disorders (%)"]== max(df["Anxiety disorders (%)"])]
# Out:
#       index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 4016   4016  New Zealand  NZL  2002          0.339223             1.195859
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 4016             0.635264                8.96733                2.141658
#
#       Depression (%)  Alcohol use disorders (%)
# 4016        4.125419                   1.447662

# %%
min(df["Depression (%)"])
df[df["Depression (%)"]== min(df["Depression (%)"])]
# Out:
#     index   Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 28     28  Albania  ALB  1990          0.193413             0.695013
#
#    Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 28             0.130782               3.327587                0.497616
#
#     Depression (%)  Alcohol use disorders (%)
# 28        2.139903                   1.709465

# %%
max(df["Depression (%)"])
df[df["Depression (%)"]== max(df["Depression (%)"])]
# Out:
#       index     Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 2245   2245  Greenland  GRL  1995          0.315753             0.590903
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 2245              0.47654               5.648279                1.678836
#
#       Depression (%)  Alcohol use disorders (%)
# 2245        6.602754                   3.489129

# %%
min(df["Bipolar disorder (%)"])
df[df["Bipolar disorder (%)"]== min(df["Bipolar disorder (%)"])]
# Out:
#       index Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 1260   1260  China  CHN  1990          0.318924             0.314535
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 1260             0.085918               3.128626                1.147397
#
#       Depression (%)  Alcohol use disorders (%)
# 1260        3.573966                   0.981807

# %%
max(df["Bipolar disorder (%)"])
df[df["Bipolar disorder (%)"]== max(df["Bipolar disorder (%)"])]
# Out:
#       index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 4027   4027  New Zealand  NZL  2013          0.341031             1.206597
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 4027             0.665308                8.53867                2.036344
#
#       Depression (%)  Alcohol use disorders (%)
# 4027        3.969718                   1.956453

# %%
min(df["Drug use disorders (%)"])
df[df["Drug use disorders (%)"]== min(df["Drug use disorders (%)"])]
# Out:
#      index                  Entity Code  Year Schizophrenia (%)  \
# 705    705  Bosnia and Herzegovina  BIH  1995            0.1887
#
#     Bipolar disorder (%) Eating disorders (%)  Anxiety disorders (%)  \
# 705             0.707569             0.099508               3.360878
#
#      Drug use disorders (%)  Depression (%)  Alcohol use disorders (%)
# 705                 0.38365         2.66578                   2.826793

# %%
max(df["Drug use disorders (%)"])
df[df["Drug use disorders (%)"]== max(df["Drug use disorders (%)"])]
# Out:
#       index         Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 6103   6103  United States  USA  2017           0.33389             0.651236
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 6103             0.512844               6.635055                3.452476
#
#       Depression (%)  Alcohol use disorders (%)
# 6103         4.83561                   2.040087

# %%
min(df["Eating disorders (%)"])
df[df["Eating disorders (%)"]== min(df["Eating disorders (%)"])]
# Out:
#       index   Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 3893   3893  Myanmar  MMR  1991          0.189887             0.500032
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 3893             0.073908               3.216425                0.554288
#
#       Depression (%)  Alcohol use disorders (%)
# 3893        2.246085                   0.837158

# %%
max(df["Alcohol use disorders (%)"])
df[df["Alcohol use disorders (%)"]== max(df["Alcohol use disorders (%)"])]
# Out:
#      index   Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 524    524  Belarus  BLR  2010          0.194892             0.698158
#
#     Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 524              0.19208               2.944119                0.782906
#
#      Depression (%)  Alcohol use disorders (%)
# 524        4.093854                   5.474668

# %%
min(df["Alcohol use disorders (%)"])
df[df["Alcohol use disorders (%)"]== min(df["Alcohol use disorders (%)"])]
# Out:
#       index Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 2833   2833  Italy  ITA  1995          0.235932             0.949639
#
#      Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 2833             0.604477               5.532503                1.281482
#
#       Depression (%)  Alcohol use disorders (%)
# 2833        3.530343                    0.44694
